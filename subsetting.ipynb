# %% [markdown]
# <a href="https://colab.research.google.com/github/Ochodus/DBLab_onehot/blob/main/subsetting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import random
from google.colab.data_table import DataTable

# %%
origin_data = pd.read_excel('drive/MyDrive/DBLab_Onehot/mental_health_medical_data.xlsx')
DataTable.max_columns = 200

# %%
#증상을 array형태로 변환
def tokenizer(df):
  tokenized = df.copy()
  del_token = "[']"
  all_token = []

  for k, s in enumerate(df['symptoms']):
    symptoms = []
    for t in del_token:
      s = s.replace(t, "")
    s = s.split(',')
    for i in s:
      if len(i) > 0 and i[0] == " ":
        i = i[1:]
      symptoms.append(i)
    if symptoms[0] == "":
      symptoms.clear()

    all_token.append(symptoms)

  tokenized.drop("symptoms", axis=1, inplace=True)
  tokenized.insert(2, "symptoms", all_token, True)

  return tokenized

#각 질병의 증상 집합에서 모든 부분집합 구하기
def subset(df):
  subsetted = df.copy()
  subset = []
  for i, s in enumerate(df['symptoms']):
    if len(s) == 0:
      continue
    subsets = [[]]
    max_len = pow(2, len(s)-1)
    for t in s:
      size = len(subsets)
      for k in range(size):
        if size == max_len:
          continue
        subsets.append(subsets[k]+[t])
    for subs in subsets:
      if len(subs) > 2:
        target = subsetted['disease'].ne(df['disease'][i]).idxmin()
        new_row = pd.DataFrame([[df['disease'][i], subs, '정신건강의학과']], columns = subsetted.columns)
        subsetted = pd.concat([subsetted.iloc[:target+1], new_row, subsetted.iloc[target+1:]], ignore_index = True)

  return subsetted

# %%
origin_data['symptoms']
tokenized = tokenizer(origin_data)
tokenized.drop('Unnamed: 0', axis=1, inplace=True)
tokenized
# Out:
#        disease                                           symptoms department
# 0        강박 장애                                  [불안, 반복적인 동작, 의심]    정신건강의학과
# 1     경계성 인격장애  [의심, 약물남용, 대인관계 어려움, 조절할 수 없는 충동감, 자살의 위험, 우울,...    정신건강의학과
# 2        공황 장애  [숨막히는 느낌, 얼굴이 화끈거림, 가슴 통증, 죽음에 대한 공포, 어지러움, 발한...    정신건강의학과
# 3        금단 현상  [복시, 손떨림, 고혈압, 서맥, 저혈압, 청색증, 불안, 기운없음, 불면증, 두통...    정신건강의학과
# 4      분열정동 장애       [와해된 언어, 피해망상, 환각, 환시, 환청, 와해된 행동, 망상, 이상행동]    정신건강의학과
# ..         ...                                                ...        ...
# 59      혈관성 치매                            [언어장애, 인지장애, 감각 이상, 마비]    정신건강의학과
# 60  히스테리성 인격장애                                                 []    정신건강의학과
# 61      레트 증후군                        [상동적 행동, 인지장애, 운동장애, 정신 지체]    정신건강의학과
# 62       폐소공포증                                 [불안, 좁은 공간에서의 불안감]    정신건강의학과
# 63     과호흡 증후군  [흉부압박감, 불안, 의식 변화, 인지장애, 복부팽만감, 부정맥, 호흡곤란, 복부 ...    정신건강의학과
#
# [64 rows x 3 columns]

# %%
subsetted = subset(tokenized)
subsetted.to_excel('drive/MyDrive/DBLab_Onehot/subset_data.xlsx')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ['생리불순', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '구강건조', '근육통', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '가슴 두근거림', '얼굴이 화끈거림', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 답답', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['손떨림', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '손떨림', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '손떨림', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '손떨림', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['생리불순', '손떨림', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '생리불순', '손떨림', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '생리불순', '손떨림', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '생리불순', '손떨림', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['가슴 답답', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '가슴 답답', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['오심', '가슴 답답', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ['온몸이 떨림', '오심', '가슴 답답', '가슴 두근거림', '구강건조', '권태감', '구토', '가슴 쓰림', '복부팽만감', '두통', '어지러움', '저림']
# ...
# ['실인증', '시력 감소', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실행증', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '실행증', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '실행증', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '실행증', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '실행증', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '실행증', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '실행증', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '실행증', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실행증', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '실행증', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '실행증', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '실행증', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '실행증', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '실행증', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '실행증', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '실행증', '섬망', '판단력장애', '언어장애', '조급증', '감정 변화']
# ['기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '기억장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실행증', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '실행증', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '실행증', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '실행증', '기억장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '실행증', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '실행증', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '실행증', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '실행증', '기억장애', '언어장애', '조급증', '감정 변화']
# ['섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실행증', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '실행증', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '실행증', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '실행증', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '실행증', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '실행증', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '실행증', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '실행증', '섬망', '기억장애', '언어장애', '조급증', '감정 변화']
# ['판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실행증', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '실행증', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '실행증', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '실행증', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '실행증', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '실행증', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '실행증', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '실행증', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실행증', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '실행증', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '실행증', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '실행증', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['시력 감소', '실행증', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '시력 감소', '실행증', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['방향감각 상실', '시력 감소', '실행증', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['실인증', '방향감각 상실', '시력 감소', '실행증', '섬망', '판단력장애', '기억장애', '언어장애', '조급증', '감정 변화']
# ['읽기 자체의 문제', '읽으려 하지 않음', '눈의 피로']
# ['읽기 자체의 문제', '읽으려 하지 않음', '광과민성']
# ['읽기 자체의 문제', '눈의 피로', '광과민성']
# ['읽으려 하지 않음', '눈의 피로', '광과민성']
# ['읽기 자체의 문제', '읽으려 하지 않음', '눈의 피로', '광과민성']
# ['인지장애', '기억장애', '언어장애']
# ['인지장애', '기억장애', '변실금']
# ['인지장애', '언어장애', '변실금']
# ['기억장애', '언어장애', '변실금']
# ['인지장애', '기억장애', '언어장애', '변실금']
# ['대인관계 어려움', '산만함', '낮은 학업 성취']
# ['대인관계 어려움', '산만함', '조절할 수 없는 충동감']
# ['대인관계 어려움', '낮은 학업 성취', '조절할 수 없는 충동감']
# ['산만함', '낮은 학업 성취', '조절할 수 없는 충동감']
# ['대인관계 어려움', '산만함', '낮은 학업 성취', '조절할 수 없는 충동감']
# ['대인관계 어려움', '산만함', '충동 조절 어려움']
# ['대인관계 어려움', '낮은 학업 성취', '충동 조절 어려움']
# ['산만함', '낮은 학업 성취', '충동 조절 어려움']
# ['대인관계 어려움', '산만함', '낮은 학업 성취', '충동 조절 어려움']
# ['대인관계 어려움', '조절할 수 없는 충동감', '충동 조절 어려움']
# ['산만함', '조절할 수 없는 충동감', '충동 조절 어려움']
# ['대인관계 어려움', '산만함', '조절할 수 없는 충동감', '충동 조절 어려움']
# ['낮은 학업 성취', '조절할 수 없는 충동감', '충동 조절 어려움']
# ['대인관계 어려움', '낮은 학업 성취', '조절할 수 없는 충동감', '충동 조절 어려움']
# ['산만함', '낮은 학업 성취', '조절할 수 없는 충동감', '충동 조절 어려움']
# ['대인관계 어려움', '산만함', '낮은 학업 성취', '조절할 수 없는 충동감', '충동 조절 어려움']
# ['언어장애', '사회적 고립', '정신 지체']
# ['인내심이 부족함', '대화에 불쑥 끼어듬', '손발을 계속 움직임']
# ['언어장애', '정신 지체', '행동장애']
# ['기억장애', '언어장애', '혼돈']
# ['기억장애', '언어장애', '성격의변화']
# ['기억장애', '혼돈', '성격의변화']
# ['언어장애', '혼돈', '성격의변화']
# ['기억장애', '언어장애', '혼돈', '성격의변화']
# ['기억장애', '언어장애', '건망증']
# ['기억장애', '혼돈', '건망증']
# ['언어장애', '혼돈', '건망증']
# ['기억장애', '언어장애', '혼돈', '건망증']
# ['기억장애', '성격의변화', '건망증']
# ['언어장애', '성격의변화', '건망증']
# ['기억장애', '언어장애', '성격의변화', '건망증']
# ['혼돈', '성격의변화', '건망증']
# ['기억장애', '혼돈', '성격의변화', '건망증']
# ['언어장애', '혼돈', '성격의변화', '건망증']
# ['기억장애', '언어장애', '혼돈', '성격의변화', '건망증']
# ['기억장애', '언어장애', '지남력 장애']
# ['기억장애', '혼돈', '지남력 장애']
# ['언어장애', '혼돈', '지남력 장애']
# ['기억장애', '언어장애', '혼돈', '지남력 장애']
# ['기억장애', '성격의변화', '지남력 장애']
# ['언어장애', '성격의변화', '지남력 장애']
# ['기억장애', '언어장애', '성격의변화', '지남력 장애']
# ['혼돈', '성격의변화', '지남력 장애']
# ['기억장애', '혼돈', '성격의변화', '지남력 장애']
# ['언어장애', '혼돈', '성격의변화', '지남력 장애']
# ['기억장애', '언어장애', '혼돈', '성격의변화', '지남력 장애']
# ['기억장애', '건망증', '지남력 장애']
# ['언어장애', '건망증', '지남력 장애']
# ['기억장애', '언어장애', '건망증', '지남력 장애']
# ['혼돈', '건망증', '지남력 장애']
# ['기억장애', '혼돈', '건망증', '지남력 장애']
# ['언어장애', '혼돈', '건망증', '지남력 장애']
# ['기억장애', '언어장애', '혼돈', '건망증', '지남력 장애']
# ['성격의변화', '건망증', '지남력 장애']
# ['기억장애', '성격의변화', '건망증', '지남력 장애']
# ['언어장애', '성격의변화', '건망증', '지남력 장애']
# ['기억장애', '언어장애', '성격의변화', '건망증', '지남력 장애']
# ['혼돈', '성격의변화', '건망증', '지남력 장애']
# ['기억장애', '혼돈', '성격의변화', '건망증', '지남력 장애']
# ['언어장애', '혼돈', '성격의변화', '건망증', '지남력 장애']
# ['기억장애', '언어장애', '혼돈', '성격의변화', '건망증', '지남력 장애']
# ['긴장', '원한', '권리를 강하게 주장']
# ['긴장', '원한', '의심']
# ['긴장', '권리를 강하게 주장', '의심']
# ['원한', '권리를 강하게 주장', '의심']
# ['긴장', '원한', '권리를 강하게 주장', '의심']
# ['이인증', '비현실감', '기억장애']
# ['조절할 수 없는 충동감', '위험한 행동 반복', '낮은 지능']
# ['조절할 수 없는 충동감', '위험한 행동 반복', '낮은 학업 성취']
# ['조절할 수 없는 충동감', '낮은 지능', '낮은 학업 성취']
# ['위험한 행동 반복', '낮은 지능', '낮은 학업 성취']
# ['조절할 수 없는 충동감', '위험한 행동 반복', '낮은 지능', '낮은 학업 성취']
# ['언어장애', '인지장애', '감각 이상']
# ['상동적 행동', '인지장애', '운동장애']
# ['흉부압박감', '불안', '의식 변화']
# ['흉부압박감', '불안', '인지장애']
# ['흉부압박감', '의식 변화', '인지장애']
# ['불안', '의식 변화', '인지장애']
# ['흉부압박감', '불안', '의식 변화', '인지장애']
# ['흉부압박감', '불안', '복부팽만감']
# ['흉부압박감', '의식 변화', '복부팽만감']
# ['불안', '의식 변화', '복부팽만감']
# ['흉부압박감', '불안', '의식 변화', '복부팽만감']
# ['흉부압박감', '인지장애', '복부팽만감']
# ['불안', '인지장애', '복부팽만감']
# ['흉부압박감', '불안', '인지장애', '복부팽만감']
# ['의식 변화', '인지장애', '복부팽만감']
# ['흉부압박감', '의식 변화', '인지장애', '복부팽만감']
# ['불안', '의식 변화', '인지장애', '복부팽만감']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '복부팽만감']
# ['흉부압박감', '불안', '부정맥']
# ['흉부압박감', '의식 변화', '부정맥']
# ['불안', '의식 변화', '부정맥']
# ['흉부압박감', '불안', '의식 변화', '부정맥']
# ['흉부압박감', '인지장애', '부정맥']
# ['불안', '인지장애', '부정맥']
# ['흉부압박감', '불안', '인지장애', '부정맥']
# ['의식 변화', '인지장애', '부정맥']
# ['흉부압박감', '의식 변화', '인지장애', '부정맥']
# ['불안', '의식 변화', '인지장애', '부정맥']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '부정맥']
# ['흉부압박감', '복부팽만감', '부정맥']
# ['불안', '복부팽만감', '부정맥']
# ['흉부압박감', '불안', '복부팽만감', '부정맥']
# ['의식 변화', '복부팽만감', '부정맥']
# ['흉부압박감', '의식 변화', '복부팽만감', '부정맥']
# ['불안', '의식 변화', '복부팽만감', '부정맥']
# ['흉부압박감', '불안', '의식 변화', '복부팽만감', '부정맥']
# ['인지장애', '복부팽만감', '부정맥']
# ['흉부압박감', '인지장애', '복부팽만감', '부정맥']
# ['불안', '인지장애', '복부팽만감', '부정맥']
# ['흉부압박감', '불안', '인지장애', '복부팽만감', '부정맥']
# ['의식 변화', '인지장애', '복부팽만감', '부정맥']
# ['흉부압박감', '의식 변화', '인지장애', '복부팽만감', '부정맥']
# ['불안', '의식 변화', '인지장애', '복부팽만감', '부정맥']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '복부팽만감', '부정맥']
# ['흉부압박감', '불안', '호흡곤란']
# ['흉부압박감', '의식 변화', '호흡곤란']
# ['불안', '의식 변화', '호흡곤란']
# ['흉부압박감', '불안', '의식 변화', '호흡곤란']
# ['흉부압박감', '인지장애', '호흡곤란']
# ['불안', '인지장애', '호흡곤란']
# ['흉부압박감', '불안', '인지장애', '호흡곤란']
# ['의식 변화', '인지장애', '호흡곤란']
# ['흉부압박감', '의식 변화', '인지장애', '호흡곤란']
# ['불안', '의식 변화', '인지장애', '호흡곤란']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '호흡곤란']
# ['흉부압박감', '복부팽만감', '호흡곤란']
# ['불안', '복부팽만감', '호흡곤란']
# ['흉부압박감', '불안', '복부팽만감', '호흡곤란']
# ['의식 변화', '복부팽만감', '호흡곤란']
# ['흉부압박감', '의식 변화', '복부팽만감', '호흡곤란']
# ['불안', '의식 변화', '복부팽만감', '호흡곤란']
# ['흉부압박감', '불안', '의식 변화', '복부팽만감', '호흡곤란']
# ['인지장애', '복부팽만감', '호흡곤란']
# ['흉부압박감', '인지장애', '복부팽만감', '호흡곤란']
# ['불안', '인지장애', '복부팽만감', '호흡곤란']
# ['흉부압박감', '불안', '인지장애', '복부팽만감', '호흡곤란']
# ['의식 변화', '인지장애', '복부팽만감', '호흡곤란']
# ['흉부압박감', '의식 변화', '인지장애', '복부팽만감', '호흡곤란']
# ['불안', '의식 변화', '인지장애', '복부팽만감', '호흡곤란']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '복부팽만감', '호흡곤란']
# ['흉부압박감', '부정맥', '호흡곤란']
# ['불안', '부정맥', '호흡곤란']
# ['흉부압박감', '불안', '부정맥', '호흡곤란']
# ['의식 변화', '부정맥', '호흡곤란']
# ['흉부압박감', '의식 변화', '부정맥', '호흡곤란']
# ['불안', '의식 변화', '부정맥', '호흡곤란']
# ['흉부압박감', '불안', '의식 변화', '부정맥', '호흡곤란']
# ['인지장애', '부정맥', '호흡곤란']
# ['흉부압박감', '인지장애', '부정맥', '호흡곤란']
# ['불안', '인지장애', '부정맥', '호흡곤란']
# ['흉부압박감', '불안', '인지장애', '부정맥', '호흡곤란']
# ['의식 변화', '인지장애', '부정맥', '호흡곤란']
# ['흉부압박감', '의식 변화', '인지장애', '부정맥', '호흡곤란']
# ['불안', '의식 변화', '인지장애', '부정맥', '호흡곤란']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '부정맥', '호흡곤란']
# ['복부팽만감', '부정맥', '호흡곤란']
# ['흉부압박감', '복부팽만감', '부정맥', '호흡곤란']
# ['불안', '복부팽만감', '부정맥', '호흡곤란']
# ['흉부압박감', '불안', '복부팽만감', '부정맥', '호흡곤란']
# ['의식 변화', '복부팽만감', '부정맥', '호흡곤란']
# ['흉부압박감', '의식 변화', '복부팽만감', '부정맥', '호흡곤란']
# ['불안', '의식 변화', '복부팽만감', '부정맥', '호흡곤란']
# ['흉부압박감', '불안', '의식 변화', '복부팽만감', '부정맥', '호흡곤란']
# ['인지장애', '복부팽만감', '부정맥', '호흡곤란']
# ['흉부압박감', '인지장애', '복부팽만감', '부정맥', '호흡곤란']
# ['불안', '인지장애', '복부팽만감', '부정맥', '호흡곤란']
# ['흉부압박감', '불안', '인지장애', '복부팽만감', '부정맥', '호흡곤란']
# ['의식 변화', '인지장애', '복부팽만감', '부정맥', '호흡곤란']
# ['흉부압박감', '의식 변화', '인지장애', '복부팽만감', '부정맥', '호흡곤란']
# ['불안', '의식 변화', '인지장애', '복부팽만감', '부정맥', '호흡곤란']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '복부팽만감', '부정맥', '호흡곤란']
# ['흉부압박감', '불안', '복부 통증']
# ['흉부압박감', '의식 변화', '복부 통증']
# ['불안', '의식 변화', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '복부 통증']
# ['흉부압박감', '인지장애', '복부 통증']
# ['불안', '인지장애', '복부 통증']
# ['흉부압박감', '불안', '인지장애', '복부 통증']
# ['의식 변화', '인지장애', '복부 통증']
# ['흉부압박감', '의식 변화', '인지장애', '복부 통증']
# ['불안', '의식 변화', '인지장애', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '복부 통증']
# ['흉부압박감', '복부팽만감', '복부 통증']
# ['불안', '복부팽만감', '복부 통증']
# ['흉부압박감', '불안', '복부팽만감', '복부 통증']
# ['의식 변화', '복부팽만감', '복부 통증']
# ['흉부압박감', '의식 변화', '복부팽만감', '복부 통증']
# ['불안', '의식 변화', '복부팽만감', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '복부팽만감', '복부 통증']
# ['인지장애', '복부팽만감', '복부 통증']
# ['흉부압박감', '인지장애', '복부팽만감', '복부 통증']
# ['불안', '인지장애', '복부팽만감', '복부 통증']
# ['흉부압박감', '불안', '인지장애', '복부팽만감', '복부 통증']
# ['의식 변화', '인지장애', '복부팽만감', '복부 통증']
# ['흉부압박감', '의식 변화', '인지장애', '복부팽만감', '복부 통증']
# ['불안', '의식 변화', '인지장애', '복부팽만감', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '복부팽만감', '복부 통증']
# ['흉부압박감', '부정맥', '복부 통증']
# ['불안', '부정맥', '복부 통증']
# ['흉부압박감', '불안', '부정맥', '복부 통증']
# ['의식 변화', '부정맥', '복부 통증']
# ['흉부압박감', '의식 변화', '부정맥', '복부 통증']
# ['불안', '의식 변화', '부정맥', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '부정맥', '복부 통증']
# ['인지장애', '부정맥', '복부 통증']
# ['흉부압박감', '인지장애', '부정맥', '복부 통증']
# ['불안', '인지장애', '부정맥', '복부 통증']
# ['흉부압박감', '불안', '인지장애', '부정맥', '복부 통증']
# ['의식 변화', '인지장애', '부정맥', '복부 통증']
# ['흉부압박감', '의식 변화', '인지장애', '부정맥', '복부 통증']
# ['불안', '의식 변화', '인지장애', '부정맥', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '부정맥', '복부 통증']
# ['복부팽만감', '부정맥', '복부 통증']
# ['흉부압박감', '복부팽만감', '부정맥', '복부 통증']
# ['불안', '복부팽만감', '부정맥', '복부 통증']
# ['흉부압박감', '불안', '복부팽만감', '부정맥', '복부 통증']
# ['의식 변화', '복부팽만감', '부정맥', '복부 통증']
# ['흉부압박감', '의식 변화', '복부팽만감', '부정맥', '복부 통증']
# ['불안', '의식 변화', '복부팽만감', '부정맥', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '복부팽만감', '부정맥', '복부 통증']
# ['인지장애', '복부팽만감', '부정맥', '복부 통증']
# ['흉부압박감', '인지장애', '복부팽만감', '부정맥', '복부 통증']
# ['불안', '인지장애', '복부팽만감', '부정맥', '복부 통증']
# ['흉부압박감', '불안', '인지장애', '복부팽만감', '부정맥', '복부 통증']
# ['의식 변화', '인지장애', '복부팽만감', '부정맥', '복부 통증']
# ['흉부압박감', '의식 변화', '인지장애', '복부팽만감', '부정맥', '복부 통증']
# ['불안', '의식 변화', '인지장애', '복부팽만감', '부정맥', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '복부팽만감', '부정맥', '복부 통증']
# ['흉부압박감', '호흡곤란', '복부 통증']
# ['불안', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '호흡곤란', '복부 통증']
# ['의식 변화', '호흡곤란', '복부 통증']
# ['흉부압박감', '의식 변화', '호흡곤란', '복부 통증']
# ['불안', '의식 변화', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '호흡곤란', '복부 통증']
# ['인지장애', '호흡곤란', '복부 통증']
# ['흉부압박감', '인지장애', '호흡곤란', '복부 통증']
# ['불안', '인지장애', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '인지장애', '호흡곤란', '복부 통증']
# ['의식 변화', '인지장애', '호흡곤란', '복부 통증']
# ['흉부압박감', '의식 변화', '인지장애', '호흡곤란', '복부 통증']
# ['불안', '의식 변화', '인지장애', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '호흡곤란', '복부 통증']
# ['복부팽만감', '호흡곤란', '복부 통증']
# ['흉부압박감', '복부팽만감', '호흡곤란', '복부 통증']
# ['불안', '복부팽만감', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '복부팽만감', '호흡곤란', '복부 통증']
# ['의식 변화', '복부팽만감', '호흡곤란', '복부 통증']
# ['흉부압박감', '의식 변화', '복부팽만감', '호흡곤란', '복부 통증']
# ['불안', '의식 변화', '복부팽만감', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '복부팽만감', '호흡곤란', '복부 통증']
# ['인지장애', '복부팽만감', '호흡곤란', '복부 통증']
# ['흉부압박감', '인지장애', '복부팽만감', '호흡곤란', '복부 통증']
# ['불안', '인지장애', '복부팽만감', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '인지장애', '복부팽만감', '호흡곤란', '복부 통증']
# ['의식 변화', '인지장애', '복부팽만감', '호흡곤란', '복부 통증']
# ['흉부압박감', '의식 변화', '인지장애', '복부팽만감', '호흡곤란', '복부 통증']
# ['불안', '의식 변화', '인지장애', '복부팽만감', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '복부팽만감', '호흡곤란', '복부 통증']
# ['부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '부정맥', '호흡곤란', '복부 통증']
# ['불안', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '부정맥', '호흡곤란', '복부 통증']
# ['의식 변화', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '의식 변화', '부정맥', '호흡곤란', '복부 통증']
# ['불안', '의식 변화', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '부정맥', '호흡곤란', '복부 통증']
# ['인지장애', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '인지장애', '부정맥', '호흡곤란', '복부 통증']
# ['불안', '인지장애', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '인지장애', '부정맥', '호흡곤란', '복부 통증']
# ['의식 변화', '인지장애', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '의식 변화', '인지장애', '부정맥', '호흡곤란', '복부 통증']
# ['불안', '의식 변화', '인지장애', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '부정맥', '호흡곤란', '복부 통증']
# ['복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['불안', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['의식 변화', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '의식 변화', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['불안', '의식 변화', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['인지장애', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '인지장애', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['불안', '인지장애', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '인지장애', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['의식 변화', '인지장애', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '의식 변화', '인지장애', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['불안', '의식 변화', '인지장애', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
# ['흉부압박감', '불안', '의식 변화', '인지장애', '복부팽만감', '부정맥', '호흡곤란', '복부 통증']
